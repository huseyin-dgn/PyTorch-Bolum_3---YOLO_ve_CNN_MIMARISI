# %% [markdown]
# # Roboflow Nedir?
#
# Roboflow, bilgisayarla görü projelerinde **veri hazırlama, etiketleme, dönüştürme, eğitim ve dağıtım** işlerini kolaylaştıran bulut tabanlı bir platformdur.
# YOLO, TensorFlow, PyTorch, Detectron2 gibi framework’lerle uyumludur.
#
# ---
#
# ## 🔹 Roboflow’un Sağladığı İşlevler
#
# ### 1. Dataset Yönetimi
# - Görselleri yükleyip **etiketleme (annotation)** yapabilirsin.
# - Dataset’i kolayca **train / valid / test** kısımlarına ayırır.
# - Etiketleri toplu düzenleyebilirsin.
#
# ### 2. Veri Zenginleştirme (Augmentation)
# - Görseller üzerinde otomatik dönüşümler uygular:
#   - Döndürme
#   - Parlaklık değiştirme
#   - Bulanıklaştırma
#   - Ölçekleme, kırpma
#   - Gürültü ekleme
# 👉 Daha fazla veri toplamadan modelini güçlendirir.
#
# ### 3. Format Dönüştürme
# - Dataset’i farklı formatlarda dışa aktarabilirsin:
#   - **YOLOv5 / YOLOv8**
#   - **COCO JSON**
#   - **Pascal VOC (XML)**
#   - **TFRecord (TensorFlow)**
#   - **CreateML (Apple)**
#
# ### 4. Model Eğitimi
# - **Roboflow Train** ile bulutta eğitim yapabilirsin.
# - Alternatif: Dataset’i indirip **lokalde PyTorch veya TensorFlow** ile eğit.
#
# ### 5. Model Dağıtımı (Deployment)
# - Eğitilmiş modeli API üzerinden kullanabilirsin:
#   - Web
#   - Mobil
#   - Edge cihazlar (Jetson Nano, Raspberry Pi vb.)
#
#
#
# ## ✅ Özet
# Roboflow, bilgisayarla görü projelerinde veri hazırlama ve model dağıtım sürecini hızlandırır.
# Sen sadece **modelin işlevine ve kullanımına odaklanırsın**.

# %% [markdown]
# ----

# %% [markdown]
# # Roboflow ile Etiketleme (Annotation) Nasıl Yapılır?
#
# Roboflow, görseller üzerinde nesneleri kolayca etiketlemeni sağlar.
# İşte adımlar:
#
#
# ## 1. Roboflow Hesabı Aç
# - [Roboflow](https://roboflow.com/) sitesine gir.
# - Google / GitHub ile hızlıca kayıt olabilirsin.
#
#
#
# ## 2. Yeni Proje Oluştur
# - **Create New Project** butonuna tıkla.
# - Proje bilgilerini doldur:
#   - **Project Type:** Object Detection (nesne tespiti)
#   - **Annotation Group:** örn. "Road and Bump"
#   - **License:** Dataset’in kullanım izni
#   - **Project Name:** örn. "Yol ve Tümsek Tespiti"
#
#
#
# ## 3. Görselleri Yükle
# - Bilgisayarındaki görselleri sürükleyip bırak.
# - Roboflow otomatik olarak yükleyecek.
#
#
#
# ## 4. Etiketleme Arayüzünü Aç
# - Yüklediğin görseli seç.
# - "Annotate" bölümüne gir.
#
#
#
# ## 5. Etiketleme İşlemi
# - Görsel üzerinde nesnenin (ör. yol, tümsek) üzerine **dikdörtgen (bounding box)** çizersin.
# - Açılan kutuya sınıf ismini yazarsın:
#   - `road`
#   - `bump`
# - Her görsel için tüm nesneleri işaretle.
# - Sağ üstten **Save** butonuna tıklamayı unutma.
#
#
#
# ## 6. Dataset’i Hazırla
# - Tüm görseller etiketlendikten sonra:
#   - **Generate Dataset** butonuna bas.
#   - Burada augmentasyon (döndürme, kırpma, gürültü ekleme vb.) seçeneklerini seçebilirsin.
#   - Dataset train/valid/test oranlarını ayarlayabilirsin (örn. 70/20/10).
#
#
# ## 7. İndirme veya Eğitim
# - Dataset hazırlandıktan sonra:
#   - YOLOv8, COCO, Pascal VOC gibi formatlarda indirebilirsin.
#   - Veya Roboflow’un kendi altyapısında eğitebilirsin.
#
#
# ## ✅ İpucu
# - Eğer çok fazla görselin varsa, Roboflow’un **AutoLabel** özelliğini kullanabilirsin.
#   Bu, küçük bir ön model ile otomatik etiket çıkarır, sen sadece düzeltirsin → zamandan tasarruf!
